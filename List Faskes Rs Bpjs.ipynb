# %% [markdown]
# https://lovia.life/id/health/bpjs

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
base = 'https://lovia.life'
url = 'https://lovia.life/id/health/bpjs'
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')

# %%
prvs = soup.find_all('h2')
v_data_m = []
NoProv = 1
for prv in prvs :
#     print(prv.get_text())
    v_prv = prv.get_text()
    lnks = prv.next_sibling.next_sibling.find_all('li')
    for lnk in lnks :
        v_lnk = lnk.find('a').get('href')
        v_name = lnk.get_text()
        v_data_m.append((NoProv, v_prv, v_name,base+v_lnk))
    NoProv = NoProv+1
#         print(lnk.find('a').get('href'))

# %%
df_m = pd.DataFrame(v_data_m, columns = ['NoProv', 'Provinsi', 'KotaKab','Link'])

# %%
df_m.groupby(['Provinsi']).count()
# Out:
#                           NoProv  KotaKab  Link
# Provinsi
# Bali                           9        9     9
# Banten                         8        8     8
# Bengkulu                      10       10    10
# D I Yogyakarta                 5        5     5
# Dki Jakarta                    6        6     6
# Gorontalo                      6        6     6
# Jambi                         11       11    11
# Jawa Barat                    27       27    27
# Jawa Tengah                   35       35    35
# Jawa Timur                    38       38    38
# Kalimantan Barat              14       14    14
# Kalimantan Selatan            13       13    13
# Kalimantan Tengah             14       14    14
# Kalimantan Timur              10       10    10
# Kalimantan Utara               5        5     5
# Kep. Bangka Belitung           7        7     7
# Kepulauan Riau                 7        7     7
# Lampung                       15       15    15
# Maluku                        11       11    11
# Maluku Utara                  10       10    10
# Nanggroe Aceh Darussalam      23       23    23
# Nusa Tenggara Barat           10       10    10
# Nusa Tenggara Timur           22       22    22
# Papua                         29       29    29
# Papua Barat                   13       13    13
# Riau                          12       12    12
# Sulawesi Barat                 6        6     6
# Sulawesi Selatan              24       24    24
# Sulawesi Tengah               13       13    13
# Sulawesi Tenggara             17       17    17
# Sulawesi Utara                15       15    15
# Sumatera Barat                19       19    19
# Sumatera Selatan              17       17    17
# Sumatera Utara                33       33    33

# %%
data = []
for i in df_m.index:
# for i in range(0, 25):
    v_prv = df_m['Provinsi'][i]
    v_kota = df_m['KotaKab'][i]
    v_links = df_m['Link'][i]
    url = v_links
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    tipes = soup.find_all('h2')
    print(i, 'of', len(df_m)-1, v_prv, v_links)
    for tipe in tipes :
        TipeFaskes = tipe.get_text()
        try :
            details = tipe.next_sibling.next_sibling.find('tbody').find_all('tr')
            for detail in details :
                no = detail.find_all('td')[0].get_text()
                KodeFaskes = detail.find_all('td')[1].get_text()
                NamaFaskes = detail.find_all('td')[2].get_text()
                try :
                    LatLongFaskes = detail.find_all('td')[2].find('a').get('href')
                except:
                    LatLongFaskes = '-'
                AlamatFaskes = detail.find_all('td')[3].get_text()
                TelpFaskes = detail.find_all('td')[4].get_text()
                data.append((i,v_prv,v_kota,v_links,TipeFaskes,no,KodeFaskes,NamaFaskes,LatLongFaskes,AlamatFaskes,TelpFaskes))
        except:
            no = '-'
            KodeFaskes = '-'
            NamaFaskes = '-'
            LatLongFaskes = '-'
            AlamatFaskes = '-'
            TelpFaskes = '-'
            data.append((i,v_prv,v_kota,v_links,TipeFaskes,no,KodeFaskes,NamaFaskes,LatLongFaskes,AlamatFaskes,TelpFaskes))
# Out:
# 0 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kota-langsa
# 1 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-gayo-lues
# 2 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-aceh-selatan
# 3 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-aceh-tenggara
# 4 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-aceh-timur
# 5 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-aceh-tengah
# 6 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-aceh-barat
# 7 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-aceh-besar
# 8 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-pidie
# 9 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-aceh-tamiang
# 10 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-aceh-utara
# 11 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-bireun
# 12 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kota-lhokseumawe
# 13 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-aceh-singkil
# 14 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-simeulue
# 15 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kota-banda-aceh
# 16 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kota-sabang
# 17 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-aceh-jaya
# 18 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-nagan-raya
# 19 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-aceh-barat-daya
# 20 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-bener
# 21 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-pidie-jaya
# 22 of 513 Nanggroe Aceh Darussalam https://lovia.life/id/health/bpjs/area/kab-subulussalam
# 23 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-nias
# 24 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-mandailing-natal
# 25 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-tapanuli-selatan
# 26 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-tapanuli-tengah
# 27 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-tapanuli-utara
# 28 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-toba-samosir
# 29 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-labuhanbatu
# 30 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-asahan
# 31 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-simalungun
# 32 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-dairi
# 33 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-karo
# 34 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-deli-serdang
# 35 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-langkat
# 36 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kota-sibolga
# 37 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kota-tanjung-balai
# 38 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kota-pematang-siantar
# 39 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kota-tebing-tinggi
# 40 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kota-medan
# 41 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kota-binjai
# 42 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-serdang-bedagai
# 43 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-samosir
# 44 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-pakpak-bharat
# 45 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-nias-selatan
# 46 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-humbang-hasundutan
# 47 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kota-padang-sidempuan
# 48 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-batu-bara
# 49 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-padang-lawas-utara
# 50 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-padang-lawas
# 51 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kota-gunungsitoli
# 52 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-nias-utara
# 53 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-nias-barat
# 54 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-labuhanbatu-utara
# 55 of 513 Sumatera Utara https://lovia.life/id/health/bpjs/area/kab-labuhanbatu-selatan
# 56 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kab-kep-mentawai
# 57 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kab-pesisir-selatan
# 58 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kab-solok
# 59 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kab-swl-sijunjung
# 60 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kab-tanah-datar
# 61 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kab-padang-pariaman
# 62 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kab-agam
# 63 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kab-lima-puluh-koto
# 64 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kab-pasaman
# 65 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kota-padang
# 66 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kota-solok
# 67 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kota-sawahlunto
# 68 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kota-padang-panjang
# 69 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kota-bukittinggi
# 70 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kota-payakumbuh
# 71 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kota-pariaman
# 72 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kab-pasaman-barat
# 73 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kab-solok-sel
# 74 of 513 Sumatera Barat https://lovia.life/id/health/bpjs/area/kab-dharmasraya
# 75 of 513 Riau https://lovia.life/id/health/bpjs/area/kab-kuantan-singingi
# 76 of 513 Riau https://lovia.life/id/health/bpjs/area/kab-indragiri-hulu
# 77 of 513 Riau https://lovia.life/id/health/bpjs/area/kab-indragiri-hilir
# 78 of 513 Riau https://lovia.life/id/health/bpjs/area/kab-pelalawan
# 79 of 513 Riau https://lovia.life/id/health/bpjs/area/kab-siak-sri-indrapura
# 80 of 513 Riau https://lovia.life/id/health/bpjs/area/kab-kampar
# 81 of 513 Riau https://lovia.life/id/health/bpjs/area/kab-rokan-hulu
# 82 of 513 Riau https://lovia.life/id/health/bpjs/area/kab-bengkalis
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\http\client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\http\client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\http\client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\http\client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-035bee680ad9> in <module>
#       6     v_links = df_m['Link'][i]
#       7     url = v_links
# ----> 8     r = requests.get(url)
#       9     soup = BeautifulSoup(r.content, 'html.parser')
#      10     tipes = soup.find_all('h2')
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\conda\conda\envs\Kuliah\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))

# %%
df5 = pd.DataFrame(data, columns = ['NoLink','Provinsi', 'KotaKab','Link','TipeFaskes','No','KodeFaskes','NamaFaskes','LatLongFaskes','AlamatFaskes','TelpFaskes'])

# %%
df5.to_csv( "Data Faskes BPJS Try 5.csv", index=False, quoting=0 )

# %%
df5.head()
# Out:
#    NoLink                  Provinsi  \
# 0       0  Nanggroe Aceh Darussalam
# 1       0  Nanggroe Aceh Darussalam
# 2       0  Nanggroe Aceh Darussalam
# 3       0  Nanggroe Aceh Darussalam
# 4       0  Nanggroe Aceh Darussalam
#
#                                              KotaKab  \
# 0  Kode Faskes dan Alamat Rumah Sakit BPJS di Kot...
# 1  Kode Faskes dan Alamat Rumah Sakit BPJS di Kot...
# 2  Kode Faskes dan Alamat Rumah Sakit BPJS di Kot...
# 3  Kode Faskes dan Alamat Rumah Sakit BPJS di Kot...
# 4  Kode Faskes dan Alamat Rumah Sakit BPJS di Kot...
#
#                                                 Link   TipeFaskes No  \
# 0  https://lovia.life/id/health/bpjs/area/kota-la...  Rumah Sakit  1
# 1  https://lovia.life/id/health/bpjs/area/kota-la...  Rumah Sakit  2
# 2  https://lovia.life/id/health/bpjs/area/kota-la...  Rumah Sakit  3
# 3  https://lovia.life/id/health/bpjs/area/kota-la...  Rumah Sakit  4
# 4  https://lovia.life/id/health/bpjs/area/kota-la...    Puskesmas  1
#
#   KodeFaskes                                         NamaFaskes  \
# 0   0001R001  RSU Cut Nyak Dhien\n                    \n    ...
# 1   0001R004  RSU Cut Meutia Langsa\n                    \n ...
# 2   0105R001  RSUD Langsa\n                    \n           ...
# 3   0105R013  RSU Ummi \n                    \n             ...
# 4   00010001  Langsa Lama\n                    \n           ...
#
#                                     LatLongFaskes  \
# 0  http://maps.google.co.id/?q=4.488058,97.947963
# 1  http://maps.google.co.id/?q=4.488088,97.947781
# 2  http://maps.google.co.id/?q=4.472208,97.975533
# 3  http://maps.google.co.id/?q=4.470376,97.991915
# 4  http://maps.google.co.id/?q=4.478172,97.949988
#
#                    AlamatFaskes           TelpFaskes
# 0    Jl. Tm Bahrum No. 1 Langsa    \n 0641-0621039\n
# 1   Jl.Garuda Kebun Baru Langsa   \n 0641- 4840076\n
# 2       Jln.A.Yani No. 1 Langsa      \n 0641-22051\n
# 3  Jln. Prof. A. Madjid Ibrahim      \n 0641-22886\n
# 4       Gampong Meurandeh Dayah  \n 0641-064121218\n
